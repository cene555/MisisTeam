# %%
# !nvidia-smi
# Out:
# Sun Oct 15 10:29:48 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.172.01   Driver Version: 450.172.01   CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100 80GB PCIe      On   | 00000000:B5:00.0 Off |                    0 |
# | N/A   39C    P0    68W / 300W |  12103MiB / 81252MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A       247      C   .../user/conda/bin/python3.9    12101MiB |
# +-----------------------------------------------------------------------------+

# %%
# %cd ~/azizov/deforum/deforum-kandinsky
# Out:
# /home/jovyan/azizov/deforum/deforum-kandinsky

# %%
# !pip install -r requirements.txt
# Out:
# WARNING: Ignoring invalid distribution -rotobuf (/home/jovyan/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ransformers (/home/jovyan/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (/home/jovyan/.local/lib/python3.9/site-packages)
# Requirement already satisfied: diffusers==0.20.2 in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (0.20.2)
# Requirement already satisfied: torch in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (2.0.1)
# Requirement already satisfied: torchvision in /home/user/conda/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (0.15.0.dev20230205+cu117)
# Requirement already satisfied: torchaudio in /home/user/conda/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (2.0.0.dev20230205+cu117)
# Requirement already satisfied: accelerate in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (0.23.0)
# Requirement already satisfied: clean-fid in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (0.1.35)
# Requirement already satisfied: colab-convert in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (2.0.5)
# Requirement already satisfied: einops in /home/jovyan/.local/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (0.6.1)
# Requirement already satisfied: ftfy in /home/jovyan/.local/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (6.1.1)
# Requirement already satisfied: ipython in /home/user/conda/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (8.9.0)
# Requirement already satisfied: ipywidgets in /home/user/conda/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (8.0.4)
# Requirement already satisfied: jsonmerge in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (1.9.2)
# Requirement already satisfied: jupyterlab in /home/user/conda/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (3.4.5)
# Requirement already satisfied: jupyter_http_over_ws in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from -r requirements.txt (line 14)) (0.0.8)
# Requirement already satisfied: kornia in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (0.7.0)
# Requirement already satisfied: matplotlib in /home/user/conda/lib/python3.9/site-packages (from -r requirements.txt (line 16)) (3.6.3)
# Requirement already satisfied: notebook in /home/user/conda/lib/python3.9/site-packages (from -r requirements.txt (line 17)) (6.4.12)
# Requirement already satisfied: numexpr in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from -r requirements.txt (line 18)) (2.8.7)
# Requirement already satisfied: omegaconf in /home/jovyan/.local/lib/python3.9/site-packages (from -r requirements.txt (line 19)) (2.0.6)
# Requirement already satisfied: opencv-python in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from -r requirements.txt (line 20)) (4.8.1.78)
# Requirement already satisfied: pandas in /home/user/conda/lib/python3.9/site-packages (from -r requirements.txt (line 21)) (1.5.3)
# Requirement already satisfied: pytorch_lightning in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from -r requirements.txt (line 22)) (2.0.9.post0)
# Requirement already satisfied: resize-right in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from -r requirements.txt (line 23)) (0.0.2)
# Requirement already satisfied: scikit-image in /home/jovyan/.local/lib/python3.9/site-packages (from -r requirements.txt (line 24)) (0.21.0)
# Requirement already satisfied: scikit-learn in /home/jovyan/.local/lib/python3.9/site-packages (from -r requirements.txt (line 25)) (1.3.0)
# Collecting timm
#   Using cached timm-0.9.7-py3-none-any.whl (2.2 MB)
# Requirement already satisfied: torchdiffeq in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from -r requirements.txt (line 27)) (0.2.3)
# Collecting transformers
#   Using cached transformers-4.34.0-py3-none-any.whl (7.7 MB)
# Requirement already satisfied: safetensors in /home/jovyan/.local/lib/python3.9/site-packages (from -r requirements.txt (line 29)) (0.3.3)
# Requirement already satisfied: albumentations in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from -r requirements.txt (line 30)) (1.3.1)
# Requirement already satisfied: more_itertools in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from -r requirements.txt (line 31)) (10.1.0)
# Requirement already satisfied: devtools in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from -r requirements.txt (line 32)) (0.12.2)
# Requirement already satisfied: validators in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from -r requirements.txt (line 33)) (0.22.0)
# Requirement already satisfied: numpngw in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from -r requirements.txt (line 34)) (0.1.2)
# Requirement already satisfied: open-clip-torch in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from -r requirements.txt (line 35)) (2.20.0)
# Requirement already satisfied: torchsde in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from -r requirements.txt (line 36)) (0.2.6)
# Requirement already satisfied: ninja in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from -r requirements.txt (line 37)) (1.11.1)
# Requirement already satisfied: pydantic in /home/user/conda/lib/python3.9/site-packages (from -r requirements.txt (line 38)) (1.10.4)
# Requirement already satisfied: xformers in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from -r requirements.txt (line 39)) (0.0.22)
# Requirement already satisfied: imageio[ffmpeg] in /home/jovyan/.local/lib/python3.9/site-packages (from -r requirements.txt (line 40)) (2.31.3)
# Requirement already satisfied: importlib-metadata in /home/user/conda/lib/python3.9/site-packages (from diffusers==0.20.2->-r requirements.txt (line 1)) (5.2.0)
# Requirement already satisfied: Pillow in /home/user/conda/lib/python3.9/site-packages (from diffusers==0.20.2->-r requirements.txt (line 1)) (9.4.0)
# Requirement already satisfied: requests in /home/user/conda/lib/python3.9/site-packages (from diffusers==0.20.2->-r requirements.txt (line 1)) (2.28.2)
# Requirement already satisfied: numpy in /home/user/conda/lib/python3.9/site-packages (from diffusers==0.20.2->-r requirements.txt (line 1)) (1.23.5)
# Requirement already satisfied: regex!=2019.12.17 in /home/user/conda/lib/python3.9/site-packages (from diffusers==0.20.2->-r requirements.txt (line 1)) (2022.10.31)
# Requirement already satisfied: filelock in /home/user/conda/lib/python3.9/site-packages (from diffusers==0.20.2->-r requirements.txt (line 1)) (3.9.0)
# Collecting huggingface-hub>=0.13.2
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 1.7 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from torch->-r requirements.txt (line 2)) (11.7.4.91)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from torch->-r requirements.txt (line 2)) (11.7.99)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from torch->-r requirements.txt (line 2)) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from torch->-r requirements.txt (line 2)) (11.7.101)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from torch->-r requirements.txt (line 2)) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from torch->-r requirements.txt (line 2)) (10.2.10.91)
# Requirement already satisfied: sympy in /home/user/conda/lib/python3.9/site-packages (from torch->-r requirements.txt (line 2)) (1.11.1)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from torch->-r requirements.txt (line 2)) (2.14.3)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from torch->-r requirements.txt (line 2)) (11.10.3.66)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from torch->-r requirements.txt (line 2)) (11.4.0.1)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from torch->-r requirements.txt (line 2)) (11.7.91)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from torch->-r requirements.txt (line 2)) (8.5.0.96)
# Requirement already satisfied: triton==2.0.0 in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from torch->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: typing-extensions in /home/user/conda/lib/python3.9/site-packages (from torch->-r requirements.txt (line 2)) (4.4.0)
# Requirement already satisfied: jinja2 in /home/user/conda/lib/python3.9/site-packages (from torch->-r requirements.txt (line 2)) (3.1.2)
# Requirement already satisfied: networkx in /home/user/conda/lib/python3.9/site-packages (from torch->-r requirements.txt (line 2)) (3.0)
# Requirement already satisfied: wheel in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch->-r requirements.txt (line 2)) (0.38.4)
# Requirement already satisfied: setuptools in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch->-r requirements.txt (line 2)) (67.1.0)
# Requirement already satisfied: lit in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from triton==2.0.0->torch->-r requirements.txt (line 2)) (17.0.1)
# Requirement already satisfied: cmake in /home/user/conda/lib/python3.9/site-packages (from triton==2.0.0->torch->-r requirements.txt (line 2)) (3.25.2)
# Requirement already satisfied: psutil in /home/user/conda/lib/python3.9/site-packages (from accelerate->-r requirements.txt (line 5)) (5.9.4)
# Requirement already satisfied: packaging>=20.0 in /home/user/conda/lib/python3.9/site-packages (from accelerate->-r requirements.txt (line 5)) (22.0)
# Requirement already satisfied: pyyaml in /home/user/conda/lib/python3.9/site-packages (from accelerate->-r requirements.txt (line 5)) (6.0)
# Requirement already satisfied: scipy>=1.0.1 in /home/user/conda/lib/python3.9/site-packages (from clean-fid->-r requirements.txt (line 6)) (1.10.0)
# Requirement already satisfied: tqdm>=4.28.1 in /home/user/conda/lib/python3.9/site-packages (from clean-fid->-r requirements.txt (line 6)) (4.64.1)
# Requirement already satisfied: json5 in /home/user/conda/lib/python3.9/site-packages (from colab-convert->-r requirements.txt (line 7)) (0.9.11)
# Requirement already satisfied: wcwidth>=0.2.5 in /home/user/conda/lib/python3.9/site-packages (from ftfy->-r requirements.txt (line 9)) (0.2.6)
# Requirement already satisfied: jedi>=0.16 in /home/user/conda/lib/python3.9/site-packages (from ipython->-r requirements.txt (line 10)) (0.18.2)
# Requirement already satisfied: stack-data in /home/user/conda/lib/python3.9/site-packages (from ipython->-r requirements.txt (line 10)) (0.6.2)
# Requirement already satisfied: matplotlib-inline in /home/user/conda/lib/python3.9/site-packages (from ipython->-r requirements.txt (line 10)) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in /home/user/conda/lib/python3.9/site-packages (from ipython->-r requirements.txt (line 10)) (3.0.36)
# Requirement already satisfied: backcall in /home/user/conda/lib/python3.9/site-packages (from ipython->-r requirements.txt (line 10)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/user/conda/lib/python3.9/site-packages (from ipython->-r requirements.txt (line 10)) (4.8.0)
# Requirement already satisfied: decorator in /home/user/conda/lib/python3.9/site-packages (from ipython->-r requirements.txt (line 10)) (5.1.1)
# Requirement already satisfied: traitlets>=5 in /home/user/conda/lib/python3.9/site-packages (from ipython->-r requirements.txt (line 10)) (5.9.0)
# Requirement already satisfied: pickleshare in /home/user/conda/lib/python3.9/site-packages (from ipython->-r requirements.txt (line 10)) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from ipython->-r requirements.txt (line 10)) (2.16.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in /home/user/conda/lib/python3.9/site-packages (from ipywidgets->-r requirements.txt (line 11)) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /home/user/conda/lib/python3.9/site-packages (from ipywidgets->-r requirements.txt (line 11)) (3.0.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/user/conda/lib/python3.9/site-packages (from ipywidgets->-r requirements.txt (line 11)) (6.21.1)
# Requirement already satisfied: jsonschema>2.4.0 in /home/user/conda/lib/python3.9/site-packages (from jsonmerge->-r requirements.txt (line 12)) (4.17.3)
# Requirement already satisfied: tornado>=6.1.0 in /home/user/conda/lib/python3.9/site-packages (from jupyterlab->-r requirements.txt (line 13)) (6.2)
# Requirement already satisfied: jupyter-server~=1.16 in /home/user/conda/lib/python3.9/site-packages (from jupyterlab->-r requirements.txt (line 13)) (1.23.5)
# Requirement already satisfied: jupyter-core in /home/user/conda/lib/python3.9/site-packages (from jupyterlab->-r requirements.txt (line 13)) (5.2.0)
# Requirement already satisfied: jupyterlab-server~=2.10 in /home/user/conda/lib/python3.9/site-packages (from jupyterlab->-r requirements.txt (line 13)) (2.19.0)
# Requirement already satisfied: nbclassic in /home/user/conda/lib/python3.9/site-packages (from jupyterlab->-r requirements.txt (line 13)) (0.5.1)
# Requirement already satisfied: six>=1.6.0 in /home/user/conda/lib/python3.9/site-packages (from jupyter_http_over_ws->-r requirements.txt (line 14)) (1.16.0)
# Requirement already satisfied: cycler>=0.10 in /home/user/conda/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 16)) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/user/conda/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 16)) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/user/conda/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 16)) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /home/user/conda/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 16)) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/user/conda/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 16)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/user/conda/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 16)) (2.8.2)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/user/conda/lib/python3.9/site-packages (from notebook->-r requirements.txt (line 17)) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/user/conda/lib/python3.9/site-packages (from notebook->-r requirements.txt (line 17)) (0.17.1)
# Requirement already satisfied: jupyter-client>=5.3.4 in /home/user/conda/lib/python3.9/site-packages (from notebook->-r requirements.txt (line 17)) (8.0.2)
# Requirement already satisfied: nbformat in /home/user/conda/lib/python3.9/site-packages (from notebook->-r requirements.txt (line 17)) (5.7.3)
# Requirement already satisfied: pyzmq>=17 in /home/user/conda/lib/python3.9/site-packages (from notebook->-r requirements.txt (line 17)) (25.0.0)
# Requirement already satisfied: prometheus-client in /home/user/conda/lib/python3.9/site-packages (from notebook->-r requirements.txt (line 17)) (0.16.0)
# Requirement already satisfied: argon2-cffi in /home/user/conda/lib/python3.9/site-packages (from notebook->-r requirements.txt (line 17)) (21.3.0)
# Requirement already satisfied: ipython-genutils in /home/user/conda/lib/python3.9/site-packages (from notebook->-r requirements.txt (line 17)) (0.2.0)
# Requirement already satisfied: nbconvert>=5 in /home/user/conda/lib/python3.9/site-packages (from notebook->-r requirements.txt (line 17)) (7.2.9)
# Requirement already satisfied: nest-asyncio>=1.5 in /home/user/conda/lib/python3.9/site-packages (from notebook->-r requirements.txt (line 17)) (1.5.6)
# Requirement already satisfied: pytz>=2020.1 in /home/user/conda/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 21)) (2022.7.1)
# Requirement already satisfied: torchmetrics>=0.7.0 in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from pytorch_lightning->-r requirements.txt (line 22)) (1.2.0)
# Requirement already satisfied: lightning-utilities>=0.7.0 in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from pytorch_lightning->-r requirements.txt (line 22)) (0.9.0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /home/jovyan/.local/lib/python3.9/site-packages (from pytorch_lightning->-r requirements.txt (line 22)) (2023.9.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/jovyan/.local/lib/python3.9/site-packages (from scikit-image->-r requirements.txt (line 24)) (1.4.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/jovyan/.local/lib/python3.9/site-packages (from scikit-image->-r requirements.txt (line 24)) (2023.8.30)
# Requirement already satisfied: lazy_loader>=0.2 in /home/jovyan/.local/lib/python3.9/site-packages (from scikit-image->-r requirements.txt (line 24)) (0.3)
# Requirement already satisfied: joblib>=1.1.1 in /home/jovyan/.local/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 25)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/user/conda/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 25)) (3.1.0)
# Collecting tokenizers<0.15,>=0.14
#   Using cached tokenizers-0.14.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
# Collecting opencv-python-headless>=4.1.1
#   Using cached opencv_python_headless-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
# Requirement already satisfied: qudida>=0.0.4 in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from albumentations->-r requirements.txt (line 30)) (0.0.4)
# Requirement already satisfied: asttokens<3.0.0,>=2.0.0 in /home/user/conda/lib/python3.9/site-packages (from devtools->-r requirements.txt (line 32)) (2.2.1)
# Requirement already satisfied: executing>=1.1.1 in /home/user/conda/lib/python3.9/site-packages (from devtools->-r requirements.txt (line 32)) (1.2.0)
# Requirement already satisfied: sentencepiece in /home/user/conda/lib/python3.9/site-packages (from open-clip-torch->-r requirements.txt (line 35)) (0.1.97)
# Requirement already satisfied: protobuf<4 in /home/user/conda/lib/python3.9/site-packages (from open-clip-torch->-r requirements.txt (line 35)) (3.19.6)
# Requirement already satisfied: trampoline>=0.1.2 in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from torchsde->-r requirements.txt (line 36)) (0.1.2)
# Requirement already satisfied: imageio-ffmpeg in /home/jovyan/.imgenv-deforum-kandinsky-azizov-0/lib/python3.9/site-packages (from imageio[ffmpeg]->-r requirements.txt (line 40)) (0.4.9)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/user/conda/lib/python3.9/site-packages (from fsspec[http]>2021.06.0->pytorch_lightning->-r requirements.txt (line 22)) (3.8.3)
# Requirement already satisfied: comm>=0.1.1 in /home/user/conda/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 11)) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/user/conda/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 11)) (1.6.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/user/conda/lib/python3.9/site-packages (from jedi>=0.16->ipython->-r requirements.txt (line 10)) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/user/conda/lib/python3.9/site-packages (from jinja2->torch->-r requirements.txt (line 2)) (2.1.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/user/conda/lib/python3.9/site-packages (from jsonschema>2.4.0->jsonmerge->-r requirements.txt (line 12)) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /home/user/conda/lib/python3.9/site-packages (from jsonschema>2.4.0->jsonmerge->-r requirements.txt (line 12)) (22.2.0)
# Requirement already satisfied: zipp>=0.5 in /home/user/conda/lib/python3.9/site-packages (from importlib-metadata->diffusers==0.20.2->-r requirements.txt (line 1)) (3.12.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/user/conda/lib/python3.9/site-packages (from jupyter-core->jupyterlab->-r requirements.txt (line 13)) (3.0.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /home/user/conda/lib/python3.9/site-packages (from jupyter-server~=1.16->jupyterlab->-r requirements.txt (line 13)) (3.6.2)
# Requirement already satisfied: websocket-client in /home/user/conda/lib/python3.9/site-packages (from jupyter-server~=1.16->jupyterlab->-r requirements.txt (line 13)) (1.5.1)
# Requirement already satisfied: babel>=2.10 in /home/user/conda/lib/python3.9/site-packages (from jupyterlab-server~=2.10->jupyterlab->-r requirements.txt (line 13)) (2.11.0)
# Requirement already satisfied: nbclient>=0.5.0 in /home/user/conda/lib/python3.9/site-packages (from nbconvert>=5->notebook->-r requirements.txt (line 17)) (0.7.2)
# Requirement already satisfied: beautifulsoup4 in /home/user/conda/lib/python3.9/site-packages (from nbconvert>=5->notebook->-r requirements.txt (line 17)) (4.11.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/user/conda/lib/python3.9/site-packages (from nbconvert>=5->notebook->-r requirements.txt (line 17)) (1.5.0)
# Requirement already satisfied: bleach in /home/user/conda/lib/python3.9/site-packages (from nbconvert>=5->notebook->-r requirements.txt (line 17)) (6.0.0)
# Requirement already satisfied: defusedxml in /home/user/conda/lib/python3.9/site-packages (from nbconvert>=5->notebook->-r requirements.txt (line 17)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/user/conda/lib/python3.9/site-packages (from nbconvert>=5->notebook->-r requirements.txt (line 17)) (0.2.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in /home/user/conda/lib/python3.9/site-packages (from nbconvert>=5->notebook->-r requirements.txt (line 17)) (2.0.5)
# Requirement already satisfied: tinycss2 in /home/user/conda/lib/python3.9/site-packages (from nbconvert>=5->notebook->-r requirements.txt (line 17)) (1.2.1)
# Requirement already satisfied: fastjsonschema in /home/user/conda/lib/python3.9/site-packages (from nbformat->notebook->-r requirements.txt (line 17)) (2.16.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/user/conda/lib/python3.9/site-packages (from pexpect>4.3->ipython->-r requirements.txt (line 10)) (0.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/user/conda/lib/python3.9/site-packages (from requests->diffusers==0.20.2->-r requirements.txt (line 1)) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/user/conda/lib/python3.9/site-packages (from requests->diffusers==0.20.2->-r requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/user/conda/lib/python3.9/site-packages (from requests->diffusers==0.20.2->-r requirements.txt (line 1)) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/user/conda/lib/python3.9/site-packages (from requests->diffusers==0.20.2->-r requirements.txt (line 1)) (1.26.14)
# Collecting huggingface-hub>=0.13.2
#   Using cached huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
# Requirement already satisfied: argon2-cffi-bindings in /home/user/conda/lib/python3.9/site-packages (from argon2-cffi->notebook->-r requirements.txt (line 17)) (21.2.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in /home/user/conda/lib/python3.9/site-packages (from nbclassic->jupyterlab->-r requirements.txt (line 13)) (0.2.2)
# Requirement already satisfied: pure-eval in /home/user/conda/lib/python3.9/site-packages (from stack-data->ipython->-r requirements.txt (line 10)) (0.2.2)
# Requirement already satisfied: mpmath>=0.19 in /home/user/conda/lib/python3.9/site-packages (from sympy->torch->-r requirements.txt (line 2)) (1.2.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/user/conda/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning->-r requirements.txt (line 22)) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/user/conda/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning->-r requirements.txt (line 22)) (6.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/user/conda/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning->-r requirements.txt (line 22)) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/user/conda/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning->-r requirements.txt (line 22)) (1.3.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/user/conda/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning->-r requirements.txt (line 22)) (1.8.2)
# Requirement already satisfied: sniffio>=1.1 in /home/user/conda/lib/python3.9/site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.16->jupyterlab->-r requirements.txt (line 13)) (1.3.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/user/conda/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->-r requirements.txt (line 17)) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /home/user/conda/lib/python3.9/site-packages (from beautifulsoup4->nbconvert>=5->notebook->-r requirements.txt (line 17)) (2.3.2.post1)
# Requirement already satisfied: webencodings in /home/user/conda/lib/python3.9/site-packages (from bleach->nbconvert>=5->notebook->-r requirements.txt (line 17)) (0.5.1)
# Requirement already satisfied: pycparser in /home/user/conda/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->-r requirements.txt (line 17)) (2.21)
# WARNING: Ignoring invalid distribution -rotobuf (/home/jovyan/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ransformers (/home/jovyan/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (/home/jovyan/.local/lib/python3.9/site-packages)
# Installing collected packages: opencv-python-headless, huggingface-hub, tokenizers, transformers, timm
# Successfully installed huggingface-hub-0.17.3 opencv-python-headless-4.8.1.78 timm-0.9.7 tokenizers-0.14.1 transformers-4.34.0

# %% [markdown]
# ## Import Dependencies

# %%
from IPython.display import Video
from deforum_kandinsky import KandinskyV22Img2ImgPipeline, DeforumKandinsky
from diffusers import KandinskyV22PriorPipeline
from transformers import CLIPVisionModelWithProjection
from diffusers.models import UNet2DConditionModel
import imageio.v2 as iio
from PIL import Image
import numpy as np
import torch
import datetime
from tqdm.notebook import tqdm
import ipywidgets as widgets
from IPython import display
import os

# %%
#  create video from generated frames
def frames2video(frames, output_path="video.mp4", fps=24, display=False):
    writer = iio.get_writer(output_path, fps=fps)
    for frame in tqdm(frames):
        writer.append_data(np.array(frame))
    writer.close()
    if display:
        display.Video(url=output_path)

# %% [markdown]
# ## Load Kandinsky 2.1 or 2.2

# %%
from diffusers import KandinskyV22PriorPipeline
from deforum_kandinsky import (
    KandinskyV22Img2ImgPipeline, 
    DeforumKandinsky,  
    KandinskyImg2ImgPipeline, 
    DeforumKandinsky
)

# load models
model_version = 2.2
device = "cuda"

if model_version == 2.2:
    image_encoder = CLIPVisionModelWithProjection.from_pretrained(
        'kandinsky-community/kandinsky-2-2-prior', 
        subfolder='image_encoder'
        ).to(torch.float16).to(device)

    unet = UNet2DConditionModel.from_pretrained(
        'kandinsky-community/kandinsky-2-2-decoder', 
        subfolder='unet'
        ).to(torch.float16).to(device)

    prior = KandinskyV22PriorPipeline.from_pretrained(
        'kandinsky-community/kandinsky-2-2-prior', 
        image_encoder=image_encoder, 
        torch_dtype=torch.float16
        ).to(device)
    decoder = KandinskyV22Img2ImgPipeline.from_pretrained(
        'kandinsky-community/kandinsky-2-2-decoder', 
        unet=unet, 
        torch_dtype=torch.float16
        ).to(device)

elif model_version == 2.1: 

    image_encoder = CLIPVisionModelWithProjection.from_pretrained(
        "kandinsky-community/kandinsky-2-1-prior", 
        subfolder='image_encoder',
        torch_dtype=torch.float16
        ).to(device)
    unet = UNet2DConditionModel.from_pretrained(
        "kandinsky-community/kandinsky-2-1", 
        subfolder='unet',
        torch_dtype=torch.float16
        ).to(device)
    prior = KandinskyPriorPipeline.from_pretrained(
        "kandinsky-community/kandinsky-2-1-prior", 
        torch_dtype=torch.float16
        ).to(device)
    decoder = KandinskyImg2ImgPipeline.from_pretrained(
        'kandinsky-community/kandinsky-2-1', 
        unet=unet, 
        torch_dtype=torch.float16
        ).to(device)
# Out:
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# Loading pipeline components...:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ## Create Animation Using GUI

# %%
def create_animation_widgets():
    prompt = widgets.Text(
        description='Prompt:', 
        layout=widgets.Layout(width='80%')
    )
    negative_prompt = widgets.Text(
        description='Neg Prompt:', 
        value="low quility, bad image, cropped, out of frame",
        layout=widgets.Layout(width='80%')
    )
    duration = widgets.FloatSlider(
        description='Duration:', 
        min=0.25, max=60, 
        value=5, step=0.25, 
        layout=widgets.Layout(width='80%')
    )
    
    acceleration = widgets.FloatSlider(
        description='Acceleration:', 
        min=0.1, max=5, 
        value=1, step=0.1, 
        layout=widgets.Layout(width='80%')
    )

    animation = widgets.Dropdown(
        options=[
            'right', 'left', 
            'up', 'down', 
            'spin_clockwise', 'spin_counterclockwise', 
            'zoomin', 'zoomout', 
            'rotate_right', 'rotate_left', 
            'rotate_up', 'rotate_down', 
            'around_right', 'around_left', 
            'zoomin_sinus_x', 'zoomout_sinus_y', 
            'right_sinus_y', 'left_sinus_y', 
            'live'
        ],
        value="right",
        description='Number:',
    )
    return widgets.VBox(children=(prompt,negative_prompt, duration, acceleration, animation))

def create_video_settings():
    return widgets.VBox(children=[
        widgets.HTML("<h2>Video Settings</h2>"),
        widgets.BoundedIntText(
            min=64,
            max=1e6,
            step=64,
            value=640,
            description='Width:',
            disabled=False
        ),
        widgets.BoundedIntText(
            min=64,
            max=1e6,
            step=64,
            value=640,
            description='Height:',
            disabled=False
        ),
        widgets.IntSlider(
            description='FPS',
            min=1, 
            max=48, 
            value=24, 
            step=1
        ),
        widgets.Text(
            description='output path:', 
            value = "video.mp4",
        )
    ])

def create_animation_tabs():
    an_widgets = widgets.Tab(layout=widgets.Layout(width='90%', height='100%'))
    an_widgets.children = [create_animation_widgets()]

    def update(a, an_widgets=an_widgets):
        if an_widgets.children[-1].children[0].value:
            an_widgets.children += (create_animation_widgets(),)
        for index, child in enumerate(an_widgets.children):
            an_widgets.set_title(index, child.children[0].value)

    def clear(a, an_widgets=an_widgets):
        children = list(an_widgets.children)
        children.pop(an_widgets.selected_index)
        an_widgets.children = tuple(children)
        an_widgets.set_title(0, "")

    add_button = widgets.Button(
        description='Add Animation',
        layout=widgets.Layout(width='44.75%')
    )
    add_button.style.button_color = "blue"
    add_button.on_click(update)

    clear_button = widgets.Button(
        description='Remove Animation',
        layout=widgets.Layout(width='44.75%')
    )
    clear_button.style.button_color = "red"
    clear_button.on_click(clear)

    return widgets.VBox([
        widgets.HTML("<h2>Animations</h2>"), 
        an_widgets,
        widgets.HBox([add_button, clear_button])
    ])


def create_start_button(animation_tabs, video_widgets, deforum, animation_display):
    def render_deforum(animation, animation_display, output_path):
        frames = []
        with animation_display:
            start_time = datetime.datetime.now() 
            progress = widgets.IntProgress(value=0, min=0, max=len(deforum))
            for index, item in enumerate(animation):
                image = item.pop("image", None)
                frames.append(image)
                progress.value = index+1
                display.clear_output(wait=True)
                display.display(image, progress)
                elapsed_time = datetime.datetime.now() - start_time
                elapsed_time -= datetime.timedelta(microseconds=elapsed_time.microseconds)
                estimated_time = (elapsed_time/(index+1)*len(deforum))
                estimated_time -= datetime.timedelta(microseconds=estimated_time.microseconds)
                
                print(f"estimated_time: {elapsed_time}/{estimated_time}")
                for key, value in item.items(): 
                    print(f"{key}: {value}")
                
            progress.style.bar_color = 'green'
        if output_path and output_path.endswith(".mp4"):
            frames2video(frames, output_path)
        else: 
            frames2video(frames)
        
            
    def parse_args(_):
        children = animation_tabs.children[1].children
        prompts = []
        negative_prompts = [] 
        durations = []
        animations = []
        accelerations = []
        
        for child in children:
            prompt, negative_prompt, duration, acceleration, animation = [x.value for x in child.children]
            if prompt: 
                prompts.append(prompt)
                negative_prompts.append(negative_prompt)
                durations.append(duration)
                accelerations.append(acceleration)
                animations.append(animation)
                
        width, height, fps = [int(x.value) for x in video_widgets.children[1:-1]]
        output_path = video_widgets.children[-1].value
        animation = deforum(
            prompts=prompts,
            negative_prompts=negative_prompts, 
            animations=animations, 
            prompt_durations=durations,
            accelerations=accelerations,
            H=height,
            W=width,
            fps=fps,
            sampler="euler"
        )
        animation = tqdm(animation, total=len(deforum))
        render_deforum(animation, animation_display, output_path)

    button = widgets.Button(
        description='Start Rendering!', 
        layout=widgets.Layout(width='90%')
    )
    button.on_click(parse_args)
    return button

# %%
video_widgets = create_video_settings()
animation_tabs = create_animation_tabs()
animation_display = widgets.Output()
start_button = create_start_button(animation_tabs, video_widgets, deforum, animation_display)
display.display(animation_display, video_widgets, animation_tabs, start_button)
# Out:
# Output()
# VBox(children=(HTML(value='<h2>Video Settings</h2>'), BoundedIntText(value=640, description='Width:', max=1000…
# VBox(children=(HTML(value='<h2>Animations</h2>'), Tab(children=(VBox(children=(Text(value='', description='Pro…
# Button(description='Start Rendering!', layout=Layout(width='90%'), style=ButtonStyle())

# %% [markdown]
# ## Generate Animation Using Wrapper

# %%
# define instance of Deforum
deforum = DeforumKandinsky(
    prior=prior,
    decoder_img2img=decoder,
    device='cuda'
)
# Out:
# Loading base model ()...
# Using cache found in /home/jovyan/.cache/torch/hub/rwightman_gen-efficientnet-pytorch_master
# Done.
# Removing last two layers (global_pool & classifier).
# Building Encoder-Decoder model..Done.

# %%
import os 

prompts=[
    "Man eating pizza in open space, Earth behind"
]



animation = deforum(
    prompts=prompts,
    animations = ["zoomout"]*len(prompts),
    prompt_durations=[4]*len(prompts),
    accelerations = [1]*len(prompts),
    H=640,
    W=1280,
    fps=24,
    save_samples=False,
    linear_transition=True,
    diffusion_cadence="2",
    strength_schedule="0:(0.13)", 
    sampler="dpmpp_2m",
    prior_seed = 2,
    seed = 1,
    midas_weight=0.3,
    use_init=False, 
    init_image = Image.open("image.png"),
)

frames = []

out = widgets.Output()
pbar = tqdm(animation, total=len(deforum))
display.display(out)

with out:
    for index, item in enumerate(pbar):
        frame = item["image"]
        frames.append(frame)
        display.clear_output(wait=True) 
        display.display(frame)
        display.display(item["depth"])
        for key, value in item.items():
            if not isinstance(value, (np.ndarray, torch.Tensor, Image.Image)):
                print(f"{key}: {value}")
            

display.clear_output(wait=True) 
frames2video(frames, "output_2_2.mp4", fps=24)
display.Video(url="output_2_2.mp4")
# Out:
#   0%|          | 0/96 [00:00<?, ?it/s]
# <video src="output_2_2.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# display.clear_output(wait=True) 
# frames2video(frames, "output_2_2.mp4", fps=24)
# display.Video(url="output_2_2.mp4")
frames[0]
# Out:
# <PIL.Image.Image image mode=RGB size=1280x640>

# %%
assert False

# %% [markdown]
# ## Create per-frame Animations from scratch

# %%
def DeforumAnimArgs():

    #@markdown ####**Animation:**
    animation_mode = "3D" #@param ['None', '2D', '3D', 'Video Input', 'Interpolation'] {type:'string'}
    max_frames = 1 #@param {type:"number"}
    border = 'replicate' #@param ['wrap', 'replicate'] {type:'string'}

    #@markdown ####**Motion Parameters:**
    angle = "0:(0)"#@param {type:"string"}
    zoom = "0:(1.00)"#@param {type:"string"}
    translation_x = "0:(0)"#@param {type:"string"}
    translation_y = "0:(0)"#@param {type:"string"}
    translation_z = "0:(0)"#@param {type:"string"}
    rotation_3d_x = "0:(0)"#@param {type:"string"}
    rotation_3d_y = "0:(0)"#@param {type:"string"}
    rotation_3d_z = "0:(0)"#@param {type:"string"}
    flip_2d_perspective = True #@param {type:"boolean"}
    perspective_flip_theta = "0:(0)"#@param {type:"string"}
    perspective_flip_phi = "0:(0)"#@param {type:"string"}
    perspective_flip_gamma = "0:(0)"#@param {type:"string"}
    perspective_flip_fv = "0:(56)"#@param {type:"string"}
    noise_schedule = "0: (0.00)"#@param {type:"string"}
    strength_schedule = "0: (0.2)"#@param {type:"string"}
    contrast_schedule = "0: (1.0)"#@param {type:"string"}
    hybrid_comp_alpha_schedule = "0:(1)" #@param {type:"string"}
    hybrid_comp_mask_blend_alpha_schedule = "0:(0.5)" #@param {type:"string"}
    hybrid_comp_mask_contrast_schedule = "0:(1)" #@param {type:"string"}
    hybrid_comp_mask_auto_contrast_cutoff_high_schedule =  "0:(100)" #@param {type:"string"}
    hybrid_comp_mask_auto_contrast_cutoff_low_schedule =  "0:(0)" #@param {type:"string"}

    #@markdown ####**Sampler Scheduling:**
    enable_schedule_samplers = False #@param {type:"boolean"}
    sampler_schedule = "0:('euler'),10:('dpm2'),20:('dpm2_ancestral'),30:('heun'),40:('euler'),50:('euler_ancestral'),60:('dpm_fast'),70:('dpm_adaptive'),80:('dpmpp_2s_a'),90:('dpmpp_2m')" #@param {type:"string"}

    #@markdown ####**Unsharp mask (anti-blur) Parameters:**
    kernel_schedule = "0: (5)"#@param {type:"string"}
    sigma_schedule = "0: (1.0)"#@param {type:"string"}
    amount_schedule = "0: (0.2)"#@param {type:"string"}
    threshold_schedule = "0: (0.0)"#@param {type:"string"}

    #@markdown ####**Coherence:**
    color_coherence = 'None' #@param ['None', 'Match Frame 0 HSV', 'Match Frame 0 LAB', 'Match Frame 0 RGB', 'Video Input'] {type:'string'}
    color_coherence_video_every_N_frames = 1 #@param {type:"integer"}
    color_force_grayscale = False #@param {type:"boolean"}
    diffusion_cadence = '2' #@param ['1','2','3','4','5','6','7','8'] {type:'string'}

    #@markdown ####**3D Depth Warping:**
    use_depth_warping = True #@param {type:"boolean"}
    midas_weight = 0.3#@param {type:"number"}
    near_plane = 200
    far_plane = 10000
    fov = 40#@param {type:"number"}
    padding_mode = 'border'#@param ['border', 'reflection', 'zeros'] {type:'string'}
    sampling_mode = 'bicubic'#@param ['bicubic', 'bilinear', 'nearest'] {type:'string'}
    save_depth_maps = False #@param {type:"boolean"}

    #@markdown ####**Video Input:**
    video_init_path =None#@param {type:"string"}
    extract_nth_frame = 1#@param {type:"number"}
    overwrite_extracted_frames = True #@param {type:"boolean"}
    use_mask_video = False #@param {type:"boolean"}
    video_mask_path ='/content/video_in.mp4'#@param {type:"string"}

    #@markdown ####**Hybrid Video for 2D/3D Animation Mode:**
    hybrid_generate_inputframes = False #@param {type:"boolean"}
    hybrid_use_first_frame_as_init_image = True #@param {type:"boolean"}
    hybrid_motion = "None" #@param ['None','Optical Flow','Perspective','Affine']
    hybrid_motion_use_prev_img = False #@param {type:"boolean"}
    hybrid_flow_method = "DIS Medium" #@param ['DenseRLOF','DIS Medium','Farneback','SF']
    hybrid_composite = False #@param {type:"boolean"}
    hybrid_comp_mask_type = "None" #@param ['None', 'Depth', 'Video Depth', 'Blend', 'Difference']
    hybrid_comp_mask_inverse = False #@param {type:"boolean"}
    hybrid_comp_mask_equalize = "None" #@param  ['None','Before','After','Both']
    hybrid_comp_mask_auto_contrast = False #@param {type:"boolean"}
    hybrid_comp_save_extra_frames = False #@param {type:"boolean"}
    hybrid_use_video_as_mse_image = False #@param {type:"boolean"}

    #@markdown ####**Interpolation:**
    interpolate_key_frames = False #@param {type:"boolean"}
    interpolate_x_frames = 20 #@param {type:"number"}
    
    #@markdown ####**Resume Animation:**
    resume_from_timestring = False #@param {type:"boolean"}
    resume_timestring = "20220829210106" #@param {type:"string"}

    return locals()

# %%
def DeforumArgs():
    #@markdown **Image Settings**
    W = 128 * 5#@param
    H = 128 * 5 #@param
    W, H = map(lambda x: x - x % 64, (W, H))  # resize to integer multiple of 64
    bit_depth_output = 8 #@param [8, 16, 32] {type:"raw"}

    #@markdown **Sampling Settings**
    seed = -1 #@param
    prior_seed = 0
    
    sampler = 'euler_ancestral' #@param ["klms","dpm2","dpm2_ancestral","heun","euler","euler_ancestral","plms", "ddim", "dpm_fast", "dpm_adaptive", "dpmpp_2s_a", "dpmpp_2m"]
    steps = 100 #@param
    scale = 7 #@param
    ddim_eta = 0.0 #@param
    dynamic_threshold = None
    static_threshold = None   

    #@markdown **Save & Display Settings**
    save_samples = False #@param {type:"boolean"}
    save_settings = False #@param {type:"boolean"}
    save_sample_per_step = False #@param {type:"boolean"}
    
    verbose = True
    display_samples = True #@param {type:"boolean"}
    show_sample_per_step = True #@param {type:"boolean"}
    
    #@markdown **Batch Settings**
    n_batch = 1 #@param
    n_samples = 1 #@param
    filename_format = "{timestring}_{index}_{prompt}.png" #@param ["{timestring}_{index}_{seed}.png","{timestring}_{index}_{prompt}.png"]
    seed_behavior = "iter" #@param ["iter","fixed","random","ladder","alternate"]
    seed_iter_N = 1 #@param {type:'integer'}
    make_grid = False #@param {type:"boolean"}
    grid_rows = 2 #@param 
    outdir = "output"

    #@markdown **True Settings**
    use_init = False #@param {type:"boolean"}
    strength = 0.2 #@param {type:"number"}
    strength_0_no_init = True # Set the strength to 0 automatically when no init image is used
    init_image = None
    # init_image = "https://cdn.pixabay.com/photo/2022/07/30/13/10/green-longhorn-beetle-7353749_1280.jpg" #@param {type:"string"}
    add_init_noise = False #@param {type:"boolean"}
    init_noise = 0.01 #@param
    # Whiter areas of the mask are areas that change more
    use_mask = False #@param {type:"boolean"}
    use_alpha_as_mask = False # use the alpha channel of the init image as the mask
    mask_file = "https://www.filterforge.com/wiki/images/archive/b/b7/20080927223728%21Polygonal_gradient_thumb.jpg" #@param {type:"string"}
    invert_mask = False #@param {type:"boolean"}
    # Adjust mask image, 1.0 is no adjustment. Should be positive numbers.
    mask_brightness_adjust = 1.0  #@param {type:"number"}
    mask_contrast_adjust = 1.0  #@param {type:"number"}
    # Overlay the masked image at the end of the generation so it does not get degraded by encoding and decoding
    overlay_mask = True  # {type:"boolean"}
    # Blur edges of final overlay mask, if used. Minimum = 0 (no blur)
    mask_overlay_blur = 5 # {type:"number"}

    #@markdown **Exposure/Contrast Conditional Settings**
    mean_scale = 0 #@param {type:"number"}
    var_scale = 0 #@param {type:"number"}
    exposure_scale = 0 #@param {type:"number"}
    exposure_target = 0.7 #@param {type:"number"}

    #@markdown **Color Match Conditional Settings**
    colormatch_scale = 0 #@param {type:"number"}
    colormatch_image = "https://www.saasdesign.io/wp-content/uploads/2021/02/palette-3-min-980x588.png" #@param {type:"string"}
    colormatch_n_colors = 4 #@param {type:"number"}
    ignore_sat_weight = 0 #@param {type:"number"}

    #@markdown **CLIP\Aesthetics Conditional Settings**
    clip_name = 'ViT-L/14' #@param ['ViT-L/14', 'ViT-L/14@336px', 'ViT-B/16', 'ViT-B/32']
    clip_scale = 0 #@param {type:"number"}
    aesthetics_scale = 0 #@param {type:"number"}
    cutn = 1 #@param {type:"number"}
    cut_pow = 0.0001 #@param {type:"number"}

    #@markdown **Other Conditional Settings**
    init_mse_scale = 0 #@param {type:"number"}
    init_mse_image = "https://cdn.pixabay.com/photo/2022/07/30/13/10/green-longhorn-beetle-7353749_1280.jpg" #@param {type:"string"}
    blue_scale = 0 #@param {type:"number"}
    
    #@markdown **Conditional Gradient Settings**
    gradient_wrt = 'x0_pred' #@param ["x", "x0_pred"]
    gradient_add_to = 'both' #@param ["cond", "uncond", "both"]
    decode_method = 'linear' #@param ["autoencoder","linear"]
    grad_threshold_type = 'dynamic' #@param ["dynamic", "static", "mean", "schedule"]
    clamp_grad_threshold = 0.2 #@param {type:"number"}
    clamp_start = 0.2 #@param
    clamp_stop = 0.01 #@param
    grad_inject_timing = list(range(1,10)) #@param

    #@markdown **Speed vs VRAM Settings**
    cond_uncond_sync = True #@param {type:"boolean"}
    precision = 'autocast' 
    C = 4
    f = 8

    cond_prompt = ""
    cond_prompts = ""
    uncond_prompt = ""
    uncond_prompts = ""
    timestring = ""
    init_latent = None
    init_sample = None
    init_sample_raw = None
    mask_sample = None
    init_c = None
    seed_internal = 0

    return locals()

# %%
import gc, math, os, pathlib, subprocess, sys, time, random
from types import SimpleNamespace
from deforum_kandinsky import render_animation, render_image_batch, render_interpolation, render_input_video
from deforum_kandinsky.helpers.prompts import Prompts

animation_prompts = {
    0: "a beautiful apple, trending on Artstation",
    24: "a beautiful banana, trending on Artstation",
    48: "a beautiful coconut, trending on Artstation",
    72: "a beautiful durian, trending on Artstation",
}
negative_prompts = {
    0: "bad image, cropped image"
}
cond, uncond = Prompts(prompt=animation_prompts, neg_prompt=negative_prompts).as_dict()
args = SimpleNamespace(**DeforumArgs())
anim_args = SimpleNamespace(**DeforumAnimArgs())
anim_args.max_frames = 96+1

args.timestring = time.strftime('%Y%m%d%H%M%S')
args.strength = max(0.0, min(1.0, args.strength))

if args.seed == -1:
    args.seed = random.randint(0, 2**32 - 1)
if not args.use_init:
    args.init_image = None
if args.sampler == 'plms' and (args.use_init or anim_args.animation_mode != 'None'):
    print(f"Init images aren't supported with PLMS yet, switching to KLMS")
    args.sampler = 'klms'
if args.sampler != 'ddim':
    args.ddim_eta = 0

if anim_args.animation_mode == 'None':
    anim_args.max_frames = 1
elif anim_args.animation_mode == 'Video Input':
    args.use_init = True

# clean up unused memory
gc.collect()
torch.cuda.empty_cache()

anim_args.video_init_path = "video.mp4"
anim_args.animation_mode = 'Video Input'


# dispatch to appropriate renderer
if anim_args.animation_mode == '2D' or anim_args.animation_mode == '3D':
    animation = render_animation(deforum.root, anim_args, args, cond, uncond)
elif anim_args.animation_mode == 'Video Input':
    animation = render_input_video(deforum.root, anim_args, args, cond, uncond)
elif anim_args.animation_mode == 'Interpolation':
    animation = render_interpolation(deforum.root, anim_args, args, cond, uncond)
else:
    animation = render_image_batch(deforum.root, args, cond, uncond)  

pbar = tqdm(animation, total=anim_args.max_frames-1)
frames = []
out =  widgets.Output()
display.display(out)
with out:
    for item in pbar:
        image = item.pop('image', None)
        frames.append(image)
        display.clear_output(wait=True)
        display.display(image)
        for key, value in item.items():
            print(f"{key}: {value}")
